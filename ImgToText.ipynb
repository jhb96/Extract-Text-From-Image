# %% [markdown]
# # EXTRACT TEXT TO IMG

# %% [markdown]
# ## Configurations

# %%
api_key = "" # Get your API KEY for FREE registering in https://ocr.space/ocrapi/freekey
images_folder = "images" # Folder with images
language = "spa" 
version = 5 # Check differents API versions. Read updates here https://ocr.space/ocrapi

# %% [markdown]
# ## Methods definitions

# %%
import os, base64, requests, asyncio

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tiff") # VALID IMAGE EXTENSIONS
api_endpoint = "https://api.ocr.space/parse/image"

async def extractText(image_path):
    try:
        # Read the image file and encode it as a base64 string
        with open(image_path, "rb") as f:
            extension = os.path.splitext(image_path)[1][1:]
            image_data = f.read()
            image_data_base64 = base64.b64encode(image_data).decode("utf-8")

        # Create the base64-encoded image string in the correct format
        base64_image = f"data:image/{extension};base64,{image_data_base64}"

        #print(f"Making API call to {api_endpoint}...")
        # Make the API call
        response = requests.post(api_endpoint, data={
            "apikey": api_key,
            "base64Image": base64_image,
            "language": language,
            "OCREngine":5
        })
        #print(response.json())
        return response.json()["ParsedResults"][0]["ParsedText"]
    except Exception as e:
        print(e)
        return "FAILED"

def textToFile(text, file, format = "txt", output_folder = "Output"):
    try:
        if format == "pdf":
            # and in a pdf file
            from fpdf import FPDF

            pdf = FPDF()
            pdf.add_page()
            pdf.set_font("Arial", size=12)
            pdf.cell(200, 10, txt=text, ln=1, align="C")
            pdf.output(f"{output_folder}/{file}.pdf")
        
        elif format == "word":
            # and in a word file
            from docx import Document

            document = Document()
            document.add_paragraph(text)
            document.save(f"{output_folder}/{file}.docx")

        else:
            # and in a txt file
            with open(f"{output_folder}/{file}.txt", "w") as f:
                f.write(text)
    except Exception as e:
        print(e)

async def processImage(image_path):
    try:
        print(f"Processing {image_path}...")
        # Extract text from the image
        text = await extractText(image_path)
        #print(f"Text for {image_path} is {text}")
        # Create a file with the extracted text
        file_name = os.path.splitext(os.path.basename(image_path))[0]
        textToFile(text, file_name, format = "word")
    except Exception as e:
        print(e)

async def main():
    try:
        image_files = [os.path.join(images_folder, file) for file in os.listdir(images_folder) if file.lower().endswith(image_extensions)]
        print(f"Nº images to process: {len(image_files)}")
        print(f"Image files: {image_files}")
        tasks = [asyncio.create_task(processImage(image)) for image in image_files]
        await asyncio.gather(*tasks)
    except Exception as e:
        print(e)
        raise e

# %% [markdown]
# ## Execution

# %%
# Run the main function
await main()
# Out:
# Image files: ['images/poesias\\A mi hija Nuria.jpeg', 'images/poesias\\cinco_años_sin_mi_niño.jpeg', 'images/poesias\\Dim dim dom.jpeg', 'images/poesias\\El de los ojitos negros.jpeg', 'images/poesias\\Es otra Navidad.jpeg', 'images/poesias\\Esta casa este lugar.jpeg', 'images/poesias\\Estamos viviendo crisis.jpeg', 'images/poesias\\Jovita soy miguelito.jpeg', 'images/poesias\\Juanjito.jpeg', 'images/poesias\\mañanitas.jpeg', 'images/poesias\\mi niño lindo esta triste.jpeg', 'images/poesias\\miguel .jpeg', 'images/poesias\\miguel 2.jpeg', 'images/poesias\\Miguel ocho años.jpeg', 'images/poesias\\Miguelito .jpeg', 'images/poesias\\Niña preciosa.jpeg', 'images/poesias\\Palomita mensajera (2).jpeg', 'images/poesias\\por un buen familiar.jpeg', 'images/poesias\\querido miguel 1.jpeg', 'images/poesias\\querido miguel 2.jpeg', 'images/poesias\\querido miguel 3.jpeg', 'images/poesias\\Querido Miguel desde el cielo.jpeg', 'images/poesias\\querido miguel.jpeg', 'images/poesias\\te cuento un cuento.jpeg', 'images/poesias\\tu primera comunión.jpeg']
# Processing images/poesias\A mi hija Nuria.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\A mi hija Nuria.jpeg is g
# jeru
# eroueIsuos u00
# §
# eudaje DuOs epia pasos g CHInE g ? tierna D!ANIS a
# 8 88 g §E 2
# "IOWIE
# -
# ep!A
# s!uos eun
# 8 3
# BLINN EL!Y TW reindasuoo verdes H ezueladse oso afo lejanía > C 8 s0 poy TH opuepnÁy > n g CHOL DE REO
# 2
# 2 2
# como
# E
# esfuerzo,
# 2 8
# g
# §
# 198
# 5398 HoYo su ugIsa 101 umb
# 9
# x
# §
# ~ P
# ¿
# g
# §
# 5
# Processing images/poesias\cinco_años_sin_mi_niño.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\cinco_años_sin_mi_niño.jpeg is Niño
# €
# opunui 3359 PABLO estrellas, HIN ounsns tiernas. JE PIALO niño 3 TROTE epuaid
# 5% 8
# tesoro
# S
# ¿Biduasne n
# 5
# ~ 5 § g
# 5
# = E
# E
# g - .
# enb
# ofen&u
# outu
# §
# '=
# 3
# Cinco Años:
# viniste
# como
# ouues? aquie
# BIQuasa.id oqnu De ILLINDO:
# en u/S O Hu
# Cinco años
# ¿espaden 5 g HE % g B1u3 [OIA
# -
# T no peo nado l
# 3 E
# llorando
# soñando con
# E
# PELO PULIDO EIN equIe
# guad e se
# g
# é g
# é
# niño!
# 8 5
# e
# 2
# 3 > 2 g
# mure duros /
# anoso = melodías
# E
# cinco años
# 3 8
# >
# >
# =
# ¿osed enO?
# ¿Porqué
# milagro
# T
# &
# § anbIod
# JIAIA
# apsap
# alívianos
# opuena
# >
# sowedo:
# Processing images/poesias\Dim dim dom.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Dim dim dom.jpeg is bu din , Inudres
# Trau Qas Carnpoues
# varog a Maullimel
# cru lo
# Maquelity
# AD IrI una fines
# Don, dun, dudia
# dadi din r daudia,
# dan y dir;
# Len campauss
# danohn:
# Gut hoy lu Beleu
# Juegan, 'contan, Autudu tallau.
# Queu
# ou de J celo Var tocana?
# B
# muposhl, iline, talam,
# Aun as 4 DurArI Lom bien Tom bien E
# anvi las toca W gret i Talan
# Dur din ,Jinda
# Las campanas qu
# hoy en Bolon
# Jurooui
# ¿autau, fueum, lolta
# L Guain fan
# de moche las tocara ®
# FI Var quelito Junto al fatale
# Ao
# Las torone_1an, bun , ton becu
# hollan Lugza, MiGuer
# Tacua)
# como Ara clun tenton a Miguel i Talan,.
# U
# Te Buen eur Magul', Colais
# Fe aun vul Vele gual
# Talan
# 'CacHip tren pre, Nispul y Talane
# Din din dios din
# •C
# w nu a u uY n N N
# Processing images/poesias\El de los ojitos negros.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\El de los ojitos negros.jpeg is El de los ojitos negros
# EI de los
# ojitos negros
# el de la cara divina
# el de los dientes de
# perlas
# el de risas cantarinas
# el de los rizos de seda
# y el hoyito en las mejillas
# ¡El niño de mis amores!
# ¡La alegría de mi vida!
# ¡el alivio de mis penas!
# ¡Bálsamo de mis heridas!
# Está sufriendo en el lecho
# como una paloma herida.
# ¡quisiera morir por él.
# quisiera darle mi vida,
# no quiero verle sufrir.
# sí quiero ver su alegría!
# ¿qué haría yo porque esto fuera
# una maldita mentira,
# que no
# hubiera sucedido
# que mi mente está aturdida
# qué ese llanto no es su llanto
# qué soñé una pesadilla?
# ¡qué daría
# yo por ver
# otra vez su cara linda
# con sus ojitos alegres
# y su risa cristalina./
# Palabras como leucemia
# quimioterapia, pie o vía
# no existieran, son efecto
# de mi obtusa fantasía.
# ¡Un milagro, por
# favor!
# ¡Un milagro! Tengo prisa
# de ver a mi niño sano
# ¡Tú lo puedes Virgencita!
# y te prometo que iré
# hasta tu pequeña ermita
# con mi niño a darte gracias.
# ¡Cúramelo, Madrecita!
# Processing images/poesias\Es otra Navidad.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Es otra Navidad.jpeg is Nuria
# fiesta
# JEJU8)
# E
# QUUIR3 luI 000!
# eland
# sientan
# ama
# 9
# cantar.
# 5
# c TaL Y
# espiritu
# perdonar,
# -
# cantar.
# exoue oues
# lejano hospital
# Dios -¡Jequed
# cama
# g
# §
# g
# epino
# 5
# Es otra Navidad
# Jendsns
# PJODE
# g
# ~
# PIOINE
# eunsns
# serp
# §
# e e caperas deseadas la meadas
# sopiondeJ comentan
# mesa la o se cie sienta 9 0
# IBIO|I 2
# §
# niño
# g
# 3
# g
# §
# g
# Po
# ~
# T 8
# §
# g
# FI
# 5
# alegres sobresaltos,
# *7
# d
# pepIAen
# familia. por la
# comparten unidos
# todos quieren JEJUBO 9
# §
# Navid.
# 2 TO 19 S9 DI IRA POCO TIEST esto E
# opel pe
# DE ES ge e
# Ce a als Navidad a ose n g
# E g
# -
# >
# 31qes? d l
# Sobre una blanca ewied
# C
# *T.
# 7
# co
# g
# Navidad
# PIOLIEDE
# pIQueIsa 35
# g
# 8
# 8
# 33
# Co § 2
# Navidad
# 8 8
# Navidad
# Brindan
# OU!N
# §
# Go
# ~
# L
# llorando
# -
# aun eled
# L
# §
# CO
# eSOJo|quie1 ZOA con
# pe piAen eno
# eun!
# madre
# Está
# S , S
# "e duraquos
# >
# <
# 2
# eLosqV
# Processing images/poesias\Esta casa este lugar.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Esta casa este lugar.jpeg is opepino eny apuer sen
# ¡estup onsonu opono
# opefo8uooe A 315U1,
# ¡earp8ue esodsa X
# apew e¡pnbe ounu ano
# jew ous!w pop esald
# guow es auped ns
# JE JISIA E OIAJOA $3T
# bored ensaluis el A
# * mejuos supod 303J1,.
# 'uguesed soue SoT
# JESEO E DIALOA as anÒ
# aped ns u0o uOJIA!A
# seu soue sop J0Áe N
# (supewi uis A) oueuuay ns u0?
# ep ol supeu eun ano
# sopepio sof uos owo
# ¡etoodsa uni o8je aq
# sopeaud sofiy sns J3
# reipawai sipod on
# opewaysuoo suped ns
# zedes panbe eupuaL
# sopequoo ¡eur soye saL
# ¡ew ue8 un ap ounw A
# sofry a osodsa ns e olog E
# [eapi supew 21sg
# soye soood uia^ u03
# buje ns op olluq ¡e ano
# opuannsa tu o¡sney sew uis
# eurep bIl!ouas eun aq
# o1qand 31sa ua OpIoEn
# ¡euno; "ropefequil
# 'sauoisuajaid uis '|etAor'
# ze8es K ajua13dwo)
# u3Aof ojsande jenbe ag
# olaya1 au of apuoa
# ojuaiwguodwoo ns
# u0o
# ofadsa f ein8 uouang
# odwan pnbe ua anb so1 ag
# copianoai ja eupe !w aa
# supo.uap ut18 us aureoug
# 03.1213 I3 OIQU2|'S u2 X
# aypou e| u2 opue¡duaquo
# *sopanoai sojue) 182043 € X
# mesaj!uew BuQuI aW
# uOJIA!A sauped siu apuog
# re8nj ajsa 'esto esg
# JE8n, 5155 "ESES EIST
# Processing images/poesias\Estamos viviendo crisis.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Estamos viviendo crisis.jpeg is PRESERRECCEENDELECCEECELEN
# 1 pineromn
# V Way
# LEa LAmIMP
# Wp Wn O Na m7 COh
# onapr
# crimen ist
# ond
# GUIMA LoaraRIN
# E
# Jourlan
# Ludid.
# 3
# 2
# 3
# 10
# en eco, al 3
# pame una Lamas
# Suro
# ansou
# n en are
# Auro
# 1
# E1 la vuo. cuns CE3 huyen couber
# I
# Norte MO
# S
# &
# g
# E
# ComiNEn Conversa
# §
# 2791 nea. seamo
# 82 Qui
# hou W san proca vulaliri estucu 8 3
# g cAlemos moniore wwdas
# GorgU Quin
# 2
# 5
# SE
# nara 3 g 3 ar { Prin § §
# peruiras reudo
# Anuda bru
# Processing images/poesias\Jovita soy miguelito.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Jovita soy miguelito.jpeg is JOVITA : SOY MIGUELITO
# Hay alegría en el cielo,
# las puertas se van a abrir,
# porque ha llegado Jovita,
# ¡Ya ha dejado de sufrir!
# Un angelito risueño,
# la ha salido recibir
# ¡Te conozco, eres Jovita!
# ¡Cómo cuidabas de mí
# cuando estaba mi mamita
# cansada y solía ir
# a recuperarse un poco
# para poder resistir!
# Jovita, soy Miguelito,
# ¿recuerdas? ¡Cuántos momentos!
# yo enfermito, tú a mi lado
# contándome lindos cuentos.
# Dios te lo
# pague Jovita,
# Él te premiará por ello,
# y allá en la Tierra a otros niños,
# que también están enfermos,
# les mandará "otras Jovitas"
# para que cuiden de ellos.
# Nosotros aquí en el cielo,
# recordando aquellos tiempos…
# y
# otra vez me contarás,
# poémas, bonitos cuentos.
# Tu ejemplo les ha dejado,
# a cuidadores y enfermos,
# amigos y familiares,
# ¡Jovita! un grato recuerdo.
# (Con cariño te recuerdo, Jovita)
# M° Lucía Vega, la llallita de Miguel.
# Processing images/poesias\Juanjito.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Juanjito.jpeg is Hoy sur en el dum de u aunogle
# rui quajo
# meto Secauiste
# hor 'lalli te felicita
# n ruca dia muilvos leo tri
# Con lame (nlus can
# paus
# 1 Gal ls parodi lon
# Ar frutan.do de la
# Luct
# Quino muroluo 4 Un put,
# u le ¿violes Ciru
# k olarle
# ur a ( urt
# a
# Manca
# Apac
# 1
# Ui
# quelk
# par Que ayuda AC Joy lacado
# Da
# y Fardo Terpoo
# Drein, pree,
# Processing images/poesias\mañanitas.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\mañanitas.jpeg is †A Ca4. Lou Lou fresner (ande,
# fas Lou. Taba
# l ru bernal
# A Las muliculvas forta
# leo4 ke Lan cauto ep
# a t
# wa
# la
# neGrears
# lenda LATE bot
# ADIPOGN
# Q pudro
# Lecharte saludare
# se atponry ader
# tren crealeudos
# din puesto a felestarte.
# des Bul
# ley wocnk
# A blaus
# reatar de
# L palos
# fre,
# 7 eu
# la Pla del Boutsu
# calabou lo russeuru
# Processing images/poesias\mi niño lindo esta triste.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\mi niño lindo esta triste.jpeg is Mi niño lindo está triste
# Mi niño lindo está triste
# mi niño no come apenas
# ya no ríe como antes
# ya
# no cuenta las estrellas.
# Ya se cansa cuando corre
# ya con su gato no juega
# Cógeme llalla, no puedo
# andar, me duelen las piernas-
# ¿qué le pasa a mi lucero?
# ¿Por qué no me he dado cuenta
# que sus ojitos alegres
# ahora miran con
# tristeza?
# ¿Qué tiene mi niño lindo?
# ¿Por qué mi
# niño no juega?
# ¿Por qué
# no canta el cantar
# de la bruja Berenguela?
# ¡Mi
# niño lindo está enfermo!
# ¿Qué le ha pasado a mi perla?
# Una enfermedad cruel,
# cruel, maligna y traicionera
# se ha adentrado en su organismo
# y como una sanguijuela
# sedienta le ha succionado
# y envenenado sus células.
# ¡Ven cariño de mi vida!
# ¿No te asustes
# mi lucero!
# ¡qué
# mamaita aprendió
# a curar niños enfermos!
# ¿Cómo iba a pensar qué tú
# serías de los primeros?
# Con amor ella te cura
# con sus
# compañeros médicos,
# y llalla te da besitos
# para que pronto estés bueno.
# llallita, di que se vayan,
# qué no me pongan goteros,
# qué no me den pinchacitos,
# que me duele y tengo miedo-
# Así empezó tu calvario
# ¿Niño lindo! ¡Niño bueno!
# mamá y papá están contigo
# Processing images/poesias\miguel .jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\miguel .jpeg is Miguel
# Joulos Todo, ¿ha ur
# efu
# favor la Fucaratik
# en tu compama Inquel
# ale bramas ente dis
# Va aunar y
# ara
# ver pousalle
# cumpliendo con d clever
# mando educado , auwa ole,
# cora tu sesuda ta un art,
# Venere A Latm amneo1,
# Opul nue
# an Hon
# un Rulen convencer,
# el urol comno,
# M perder unr4
# Balon
# lé.
# Sul
# Car la Imins
# intencion
# Atino ouxs
# Latos
# estevam
# S. ST
# teerdaudo u 64, frausu
# uvando te quina al cilo.
# Te Lunes
# 'hut
# Processing images/poesias\miguel 2.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\miguel 2.jpeg is hdrs
# farsa
# Inusul
# eruaus puno maqut:
# a oseuq, Eses. yuserlrd lun y qusa
# daur Tu cusadd M la apoyo
# Tu
# berrinke4 tu energia
# del paso aut mas erecemin
# mas I noblemas encoramo
# crus tierras movedisas
# Oul Te arranrou
# ninta el fanesp.
# Mues ¿u Tu ausda Vingual
# He Qui uk Tender la unawo
# para LuD
# perder la fe
# y Muer emu
# foreu cutauo
# leasin Herido eu aleloule
# estudor-son rurpousaible
# van 'nona dalusute
# forr un buen Paloap.
# TalL
# Apurdo Insul Me ne sabemos
# cu tabe
# dil Fau sopeca
# zulimn
# †
# E fue
# para surmatur,
# comia vasur a Huidar,
# ensoniTouts Unaluel
# de curar Cu aumr
# que
# mun lot maculpre
# ularr
# manta alea y corazzu
# fer "mi a m
# alrededr
# lassy lu ent4 Lucrntia
# Tenso duceit se tonto pedisur ayuda a bus
# e couL a Nuera
# Processing images/poesias\Miguel ocho años.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Miguel ocho años.jpeg is puc
# parkr
# fatud
# Oclu puer
# J geos jacoy
# cordus®
# varr usu
# Qut Te nubesk
# al dalo;
# brioso tu copaica
# CANSo
# sucespely
# te celio de uluM
# Se pol
# laudhi Ini veeuldss
# de alpulla infancia felur,
# 1 co
# Lo
# curar calos ust Tacater
# MO Aculas
# tu cafeuda Quiero
# troza wel Juulor, Coruo hinasot
# con su aer ti ali
# aque
# y Cu sido W
# Ukese l der
# Jo en la tenie 1éx veu fauc;,
# rauda velan a tu lado
# y ular trespre, jondo se le -
# T
# (puno Luacep
# Processing images/poesias\Miguelito .jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Miguelito .jpeg is esmero
# ¿Qué traes con tanto
# escondido?
# e quiero
# MIGUELITO
# Amor y muchos te
# en la mochila
# muchos dibujitos
# de mamAd quien no olvido.
# Cuentos,
# de cuando estuve enfermito,
# juguetes y el historial
# recuerdos del hospital..
# ewewv en una oración,
# ua ouewsay !w eun canción,
# 'Quajuguas ¡w ua eded +
# todos en mi pensamiento.
# Deseos de salud y vida
# epuay ns 'sean&uewe sns
# Je!a!je / soy!u sol
# TeJO|| ou 'as sopas A
# deja que bese tu frente,
# I snsar ;osoJowe ofip
# niño bueno y cariñoso
# sufrido,..., valiente
# oquewuay4 4bwud sna
# se jejq!i ondijed jap
# creo laico Al ido
# tiruo
# wout TI 'I/ Tu
# onan/oa WID
# e
# seas laQue ns Miguelito
# del mal les apartarás
# Da!snsar ojajo ja ug
# opue qua elsa Miguelito
# resed a pelap:30!p
# abrazar ola inb a j o^ :
# ¡aquauuos ue, a pean!
# valiente oy!u un 'enug
# uel! dulce jeo!jalue
# 0|!) ja ua Jaua) e SeA
# ¡ensajao ajos ensa e
# la40 bu!lanqe ni uos anb
# Jofaw el ejuedwos
# y tu "Abu" José María.
# ¡eno e uasaujo al más bellas,
# sesos ap epjewsin3 eun
# eun / corona de estrellas
# sesojojo A sepuj sew sel
# ewoJe 13 se| ap flores
# sajouoy au!pua. ejed uos
# ap olltq ¡a / las estrellas
# ¡equoso: la Jod ¡Gracias
# "sella uos ajeuoso3 Á
# exjjos !w e auquinisose aw
# zedeou! euena|i ap Ãos
# se;ansa ser A sosojy se
# zepya A eogogad ues
# sejja ap taJopabajau
# exjewewjw e opuyq sel
# y bonita.
# Jod
# abregade.
# tan.........Y
# Processing images/poesias\Niña preciosa.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Niña preciosa.jpeg is Él dier
# le de Agot
# uaen una aura precise
# Mu Mor Ap4 LAS Luceres
# qu
# Ivo q unta
# vars
# 2Mg.
# celebra vez tas 'cucue"
# din
# unitap y
# agp1
# durearusi ALAUNALA
# Parai
# Lal Joba
# Le ser le he
# (ped.do
# Ur
# unr
# epara An
# G
# que se consplan 'les
# dere,
# 1- bide
# fuen Spir
# Processing images/poesias\Palomita mensajera (2).jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Palomita mensajera (2).jpeg is Palomita mensajera
# Palomita mensajera
# Que oteando el espacio vas
# Me arrancaron de mi vera
# A mi niño, ¿dónde está?
# Palomita, vuela y llega
# Sin descanso, hasta el lugar
# De paz, de amor y de entrega
# Que a mi niño has de encontrar
# Palomita mensajera
# Mi recadito le das
# Dile que es larga la espera
# Y que ya no puedo más.
# Paloma; dí que le quiero
# Que no dejo de llorar
# Que sin mi niño me muero
# Que a su lado quiero estar. (
# Processing images/poesias\por un buen familiar.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\por un buen familiar.jpeg is 18S.13Au00 A as renuooua ag
# uQIS830 el irupasoideA
# ENOU-BILA NS E IRIO Y
# S013W01 so.nsanu ueq: apuoc
# minuua eyanbad eun APH
# olapuas pp eljuo el y
# 081010 uy je aped p X
# oq3ouew pp ugrogad en
# ugzes u0o realdxa erea
# OJ3Jua e1p un euesed
# - u011pua q ns ?p sou x
# aure 31 enb m uuad ag
# uop je epaouos aw a lg
# euped m e of ojadsa1 uog-
# -of ou 'epueu uainb so ra
# sesos seisa un 'suped Tw A
# sola einb of Ise IS TS-
# eS0101qui31 3101531u09
# -seaipuodsa1100 a w m x
# oue 31 oqueno 3u109 g
# riaisinb ok- ofip
# 3119 A
# uouezrud as sepenw sns
# -pos ni Jewjeo eisey 2q3q-
# oIp 3] ore uPo
# ¡3 ella
# -sa tipJoouas!w ap 23190
# ¿OAEJ mod en&e sep ew?-
# ¡aquaiqure Ja BIa opiped anò!
# equisa p ejopuejadsa X
# aquary ely el ap en8y
# eqeauede ella aprel eun
# BIaQuis K a0mp 'euesuo
# esouoqe; & appuny erg
# BIaABwud e| ua Epiden
# esouuay emmjeua ejpnby
# reuod a oleq sepejeg
# epeJoqre ej reuadsap iv
# mequeo eijos anb el V
# eje8ez eun eqeure 13
# ueqendsns p iod sepol
# o1qand pop sezedes se) A
# uequien aL anb sojanbe ag
# oraude jo que8 J0Áeu eX
# ued p X of1qoo 13
# epuessuco & ofeqen uog
# re8ed odns u21q I12 A
# ESB3 nS 9A311 01
# ano
# meywey uanq un Jod
# Processing images/poesias\querido miguel 1.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\querido miguel 1.jpeg is t ordines
# QuL Te ulisl al celo,
# MAAA
# 6.
# AcLIAN,TIA
# Secristo Inquel
# Contrep esToy ramire
# hoy eu.
# Laial,
# ambo c Munes
# w a Huidor
# En mi cruzga
# reveamo t estaras,
# Conmisp
# freno,
# lo
# err arTira,
# IS
# u
# lunar Turles
# u que aliaras
# Guedo nuquel!
# Ami aneel
# ellestiall
# Opulvo
# ul aut augude,
# Y
# Ligres del mal
# Louea aio cu tos,
# Irluntad
# que huya de peli GeM),
# / - horrenhy
# Processing images/poesias\querido miguel 2.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\querido miguel 2.jpeg is tVo
# Cu Compausa
# busque La hay,
# Sal pur frenta Jocrte,
# t-bug en Viudad,
# Lot asa (ruin cointriauo
# 12 pa Untar
# a su terus Inunco
# S'
# que Da La Cruz esta,
# Convo
# Yi Aunera
# contrap chirlar,
# Cava partes estudita
# jugar!
# nu alsa
# + Y
# en Ta Laxepes
# Sul ax tera
# Marerurs penty
# or nue jaunas,
# Processing images/poesias\querido miguel 3.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\querido miguel 3.jpeg is Reudo
# Miguel
# Cou ti ço estoy Resupre
# boy
# eu
# cal
# parque nuulo ¡ nunca nunco
# te
# En
# vo,
# a olvidas
# Mi coralon
# Sesupre
# a estana'si
# Carmigo 6 bueno,
# (0
# Can pac hras
# du
# MiS Voroo Tristas
# Mo aliviarás
# I Quendo Mipel
# Mi augel Celesticl
# Que co
# gue Mo
# a'lreo
# D8
# ayudos
# del mol
# grues
# mis actos
# Le
# Me
# voluntad
# huya de pebpios,
# S bus quel la par
# Ge me neuta Preste
# obte cau londad
# le ca w
# bien ens haco
# A de pa
# inatar
# ese Jesus bueno
# 9e eu
# la Cruz esta'
# Con tico
# chorlar
# - Cono
# ,° quineo fete+ +eERCe Compartir es tvolos, red y gagor
# Si
# lE
# w al mo esta limpia
# 9% así
# sera
# Par Les pre
# estarewos Joules Lourde
# causas
# Processing images/poesias\Querido Miguel desde el cielo.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\Querido Miguel desde el cielo.jpeg is Ser ansels
# anto/an
# g
# 3
# 5 Hu
# TW
# COMA D ARMI
# minis
# 4,3 ante
# S
# E
# volaw I 3 _
# S
# 1
# comamo
# >
# dermida
# hablamos coutier
# 3
# teuhamos Toron
# VaN DENO Mm
# Contaro
# wola INTI
# E
# 2
# E
# MAsI
# g
# §
# 2
# Ona RINO
# ano w m
# 2
# M mN
# 2014 VI0 Enamy
# Gravom
# 2
# echa vor
# Desde S Aunada, coand
# g
# ave mam
# cnpm0 Dm
# & g 5 83
# Var
# Sade porto todal
# Abo
# 2 morn
# La omso parm COn
# S
# E
# 5 0
# 85
# (5<,29 Y J
# Processing images/poesias\querido miguel.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\querido miguel.jpeg is CHESPERCEEEECERRARECE
# nucoh
# mM InG
# 7
# E
# AP
# Ima §
# peliGras letrauf 00-27
# cucubo
# §
# 3 5
# horra,
# 3
# *
# 5 Conteos
# oprimio La Persona
# $ & 1
# 5
# PROR T a neme!
# % 83%3
# 3
# HorT
# 3
# orlo
# vorot
# S
# 1 I WEM ven con PoR e
# COn ace 100 1 § A I , P VAr HT
# E
# Processing images/poesias\te cuento un cuento.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\te cuento un cuento.jpeg is la experiencia de una enfermedad opulns ha
# UOZ0402 vida
# bueno. sereise A 'sowud tus
# y Jara, ofuen uoo sereing
# eludio el ap so!paw los u03
# nu 'oman8um sado mi anbuod dowo u0? OULD3 u02 llalla n Te lo dedica
# empad
# un cuento?
# ¿OIS0 [9
# nosotros todos contentos
# Mi niño otra vez feliz,
# D13n8 pf ojemnbur un como
# tu enfermedad [ew un sueño.
# spiuansasuos sns todas 40?
# HOJuos
# PIOS sopo; exed X
# Supremo top epnÃe el A
# "Oquerwuyns mi ozadue
# 4 mi niño Miguelito que
# onuanoua ns e a!les exed
# opI3n231 0S010[op
# 13Áe jonbe de girepand
# y reanudarás tu vuelo.
# Volverás a sonreir
# Tu A un niño más oulojue
# el e Virgen ns ap orqand
# ILIPA sano
# alma ,
# EN!LLEIL A
# cruel.
# opuo1 !p nqe
# lindo oytu
# "O Pn8 1N Eupuas ¿Cuándo
# 01!19A!10
# eJoue ou3no 21? ox K
# 0188
# LOP 13
# oueduie Qué
# sentirás que tienes alas
# un
# u03 Je8nf X
# uos risa onb
# Processing images/poesias\tu primera comunión.jpeg...
# Making API call to https://api.ocr.space/parse/image...
# Text for images/poesias\tu primera comunión.jpeg is TU PRIMERA COM'UNIÓN
# Esta mañana un jilguero
# Se posaba en mi ventana
# Si oyes
# un tenue revuelo
# Con sus trinos lisonjeros
# De alas a tu alrededor
# Alegre me despertaba.
# Es
# que
# han bajado
# del cielo
# Y vi en lo alto del cielo
# A desearte lo mejor.
# Al fulgor de la alborada
# Papá y Mamá emocionados
# Juguetear a un lucero
# Casi a punto de llorar
# Con la luna alborozada.
# Mirándote embelesados
# Las flores de mi balcón
# Desean poderte abrazar.
# Su perfume derramaban
# Todos los que te queremos
# Las alondras con su son
# A
# tu lado nos tendrás
# Un gran
# día me anunciaban.
# En ese día
# que sabemos
# Con tan
# dulces melodías
# Tú jamás olvidarás.
# Recordé sobresaltada
# Pide a Jesús con cariño
# Que Iñigo ¡A Dios recibías!
# Cuando esté en tu corazón
# ¡Qué fecha tan deseada!
# Que no haya ningún niño
# Con tu alma limpia y contento
# Sin pan, amor e
# ilusión.
# Caminas con ilusión
# Y yo mi "cucurruquiño"
# Con tus padres hacia el templo
# ¿Qué te voy a desear?
# pensando en tu Comunión.
# Si eres todo mi cariño
# Miguelito desde el cielo
# Y hoy contigo quiero estar.
# Compartirá tu alegria
# A Jesús le pediré
# También tu abuelita Chelo
# Y a su madre celestial
# Y tu "abu'
# José María.
# Que seas un niño con Fe
# A los ángeles, Miguel
# Bueno, obediente y leal.
# Les contará muy quedito
# En recuerdo de este día
# Aquél que comulga es "él"
# Es Iñigo, mi hermanito.
# Lleno de entrega y fervor
# Tu Mallita esta poesía
# Te dedica con amor.
# Lurd
